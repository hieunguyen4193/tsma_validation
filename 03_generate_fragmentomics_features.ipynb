# %%
import pandas as pd 
import numpy as np 
import os 
import pathlib 
from tqdm import tqdm 

import re

from helper_functions import * 
path_to_sample_readdf = "/Volumes/HNSD01/storage/TSMA_validation_readdf/reads/1-MYAAAA29TS_M525-M725"
outputdir = "./output"

samplename = path_to_sample_readdf.split("/")[-1]
path_to_save_output = f"./{outputdir}/{samplename}"
print(f"Working on sample {samplename}, output will be saved to {path_to_save_output}")

os.makedirs(path_to_save_output, exist_ok=True)

all_panels = ["Rare_cancers_panel",
              "TMD_450_panel",
              "TSMA_panel"]

for panel in all_panels:
    all_files = [item for item in pathlib.Path(path_to_sample_readdf).glob(f"{panel}/*.csv")]

    all_regions = []
    all_counts = []
    flendf = pd.DataFrame(data = {"size": np.arange(50, 351)})
    motifdf = pd.DataFrame(
        data = [f"{i}{j}{k}{l}" for i in ["A", "T", "C", "G"] for j in ["A", "T", "C", "G"] for k in ["A", "T", "C", "G"] for l in ["A", "T", "C", "G"]],
        columns = ["motif"]
    )
    def _get_read_length_on_alignment(cigar_string):
        # cigar_string = "5M1D72M"
        numbers = re.findall(r'\d+', cigar_string)
        total = sum(int(num) for num in numbers)
        return total

    path_to_all_fa = "/Volumes/HNSD01/storage/ref/hg19"
    def _get_motif_seq(path_to_all_fa, chrom, start, flen_sign, read_length):
        if flen_sign > 0:
            end = start +  4 - 1
            return get_refseq(path_to_all_fa, chrom, start, end)
        else:
            start = start + read_length - 1
            end = start
            start = start - 4 + 1
            return get_refseq(path_to_all_fa, chrom, start, end)
        
    for file in tqdm(all_files):
        regionname = file.name.replace("readdf_", "").replace(".csv", "")
        df = pd.read_csv(file, index_col = [0])
        if (df.shape[0] != 0):
            df["abs_flen"] = df["flen"].abs()
            df["read_length"] = df["cigar"].apply(lambda x: _get_read_length_on_alignment(x))
            df["motif"] = df[["chrom", "start", "flen", "read_length"]].apply(lambda x:
                _get_motif_seq(path_to_all_fa, x[0], x[1], x[2], x[3]), axis = 1)
            
            tmp_flendf = df.groupby("abs_flen")["sample"].count().reset_index()
            tmp_flendf.columns = ["size", regionname]
            flendf = flendf.merge(tmp_flendf, on = "size", how = "left").fillna(0)
            tmp_motifdf = df.groupby("motif")["sample"].count().reset_index()
            tmp_motifdf.columns = ["motif", regionname]
            motifdf = motifdf.merge(tmp_motifdf, on = "motif", how = "left").fillna(0)
        count = df.shape[0]
        all_regions.append(regionname)
        all_counts.append(count)
    depthdf = pd.DataFrame({"region": all_regions, "num_reads": all_counts})
    flendf.to_csv(f"{outputdir}/fragment_size_distribution_{panel}.csv")
    motifdf.to_csv(f"{outputdir}/motif_distribution_{panel}.csv")
    depthdf.to_csv(f"{outputdir}/depth_{panel}.csv")
# Out:
# Working on sample 1-MYAAAA29TS_M525-M725, output will be saved to ././output/1-MYAAAA29TS_M525-M725
#  42%|████▏     | 22/53 [02:10<02:40,  5.17s/it]Exception ignored in: <function Faidx.__del__ at 0x16e990700>
# Traceback (most recent call last):
#   File "/Users/hieunguyen/miniconda3/envs/pytorch/lib/python3.8/site-packages/pyfaidx/__init__.py", line 883, in __del__
#     self.__exit__()
#   File "/Users/hieunguyen/miniconda3/envs/pytorch/lib/python3.8/site-packages/pyfaidx/__init__.py", line 889, in __exit__
#     self.file.close()
# AttributeError: 'Faidx' object has no attribute 'file'
# 100%|██████████| 53/53 [03:42<00:00,  4.19s/it]
# 100%|██████████| 451/451 [23:32<00:00,  3.13s/it]
#  62%|██████▏   | 1824/2945 [26:03<16:01,  1.17it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 56
#      54 df["abs_flen"] = df["flen"].abs()
#      55 df["read_length"] = df["cigar"].apply(lambda x: _get_read_length_on_alignment(x))
# ---> 56 df["motif"] = df[["chrom", "start", "flen", "read_length"]].apply(lambda x:
#      57     _get_motif_seq(path_to_all_fa, x[0], x[1], x[2], x[3]), axis = 1)
#      59 tmp_flendf = df.groupby("abs_flen")["sample"].count().reset_index()
#      60 tmp_flendf.columns = ["size", regionname]
#
# File ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Cell In[5], line 57, in <lambda>(x)
#      54 df["abs_flen"] = df["flen"].abs()
#      55 df["read_length"] = df["cigar"].apply(lambda x: _get_read_length_on_alignment(x))
#      56 df["motif"] = df[["chrom", "start", "flen", "read_length"]].apply(lambda x:
# ---> 57     _get_motif_seq(path_to_all_fa, x[0], x[1], x[2], x[3]), axis = 1)
#      59 tmp_flendf = df.groupby("abs_flen")["sample"].count().reset_index()
#      60 tmp_flendf.columns = ["size", regionname]
#
# Cell In[5], line 43, in _get_motif_seq(path_to_all_fa, chrom, start, flen_sign, read_length)
#      41 if flen_sign > 0:
#      42     end = start +  4 - 1
# ---> 43     return get_refseq(path_to_all_fa, chrom, start, end)
#      44 else:
#      45     start = start + read_length - 1
#
# File ~/src/tsma_validation/helper_functions.py:16, in get_refseq(path_to_all_fa, chrom, start, end)
#      14 def get_refseq(path_to_all_fa, chrom, start, end):
# ---> 16     refseq = pyfaidx.Fasta(os.path.join(path_to_all_fa, "{}.fa".format(chrom)))
#      17     return(str.upper(refseq.get_seq(name = "{}".format(chrom), start = start, end = end).seq))
#
# File ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/pyfaidx/__init__.py:1090, in Fasta.__init__(self, filename, indexname, default_seq, key_function, as_raw, strict_bounds, read_ahead, mutable, split_char, filt_function, one_based_attributes, read_long_names, duplicate_action, sequence_always_upper, rebuild, build_index)
#    1084 """
#    1085 An object that provides a pygr compatible interface.
#    1086 filename:  name of fasta file or fsspec.core.OpenFile instance
#    1087 indexname: name of index file or fsspec.core.OpenFile instance
#    1088 """
#    1089 self.mutable = mutable
# -> 1090 self.faidx = Faidx(
#    1091     filename,
#    1092     indexname=indexname,
#    1093     key_function=key_function,
#    1094     as_raw=as_raw,
#    1095     default_seq=default_seq,
#    1096     strict_bounds=strict_bounds,
#    1097     read_ahead=read_ahead,
#    1098     mutable=mutable,
#    1099     split_char=split_char,
#    1100     filt_function=filt_function,
#    1101     one_based_attributes=one_based_attributes,
#    1102     read_long_names=read_long_names,
#    1103     duplicate_action=duplicate_action,
#    1104     sequence_always_upper=sequence_always_upper,
#    1105     rebuild=rebuild,
#    1106     build_index=build_index)
#    1108 self.filename = self.faidx.filename
#    1110 _record_constructor = MutableFastaRecord if self.mutable else FastaRecord
#
# File ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/pyfaidx/__init__.py:391, in Faidx.__init__(self, filename, indexname, default_seq, key_function, as_raw, strict_bounds, read_ahead, mutable, split_char, duplicate_action, filt_function, one_based_attributes, read_long_names, sequence_always_upper, rebuild, build_index)
#     389 self.filename = str(filename)
#     390 try:
# --> 391     self.file = open(filename, 'r+b' if mutable else 'rb')
#     392 except IOError:
#     393     raise FastaNotFoundError("Cannot read FASTA from file %s" % filename)
#
# KeyboardInterrupt:

# %%
df
# Out:
#        chrom    start cigar  flen  \
# 0      chr20  5297008   77M  -128
# 1      chr20  5297008   77M  -128
# 2      chr20  5297008   77M  -128
# 3      chr20  5297008   77M  -128
# 4      chr20  5297008   77M  -128
# ...      ...      ...   ...   ...
# 39739  chr20  5297182   76M  -146
# 39740  chr20  5297182   76M  -146
# 39741  chr20  5297182   76M  -146
# 39742  chr20  5297182   76M  -146
# 39743  chr20  5297182   76M  -146
#
#                                                      seq  \
# 0      TATATTTTGAGAGTGGTGGGAGGTAAAGTAGTTGGAATGTTTGAGA...
# 1      TATATTTTGAGAGTGGTGGGAGGTAAAGTAGTTGGAATGTTTGAGA...
# 2      TATATTTTGAGAGTGGTGGGAGGTAAAGTAGTTGGAATGTTTGAGA...
# 3      TATATTTTGAGAGTGGTGGGAGGTAAAGTAGTTGGAATGTTTGAGA...
# 4      TATATTTTGAGAGTGGTGGGAGGTAAAGTAGTTGGAATGTTTGAGA...
# ...                                                  ...
# 39739  GTTGGATTGAGAGTTATAGTGTGGTTGGGTGTAGGTGGGTTGTTTG...
# 39740  GTTGGATTGAGAGTTATAGTGTGGTTGGGTGTAGGTGGGTTGTTTG...
# 39741  GTTGGATTGAGAGTTATAGTGTGGTTGGGTGTAGGTGGGTTGTTTG...
# 39742  GTTGGATTGAGAGTTATAGTGTGGTTGGGTGTAGGTGGGTTGTTTG...
# 39743  GTTGGATTGAGAGTTATAGTGTGGTTGGGTGTAGGTGGGTTGTTTG...
#
#                                            methyl_string       XR       XG  \
# 0      XM:Z:h....h.z........z......h....x..xz......hx...  XR:Z:GA  XG:Z:CT
# 1      XM:Z:h....h.z........z......h....x..xz......hx...  XR:Z:GA  XG:Z:CT
# 2      XM:Z:h....h.z........z......h....x..xz......hx...  XR:Z:GA  XG:Z:CT
# 3      XM:Z:h....h.z........z......h....x..xz......hx...  XR:Z:GA  XG:Z:CT
# 4      XM:Z:h....h.z........z......h....x..xz......hx...  XR:Z:GA  XG:Z:CT
# ...                                                  ...      ...      ...
# 39739  XM:Z:.xz....z......h.x............z.x...z...xz...  XR:Z:GA  XG:Z:CT
# 39740  XM:Z:.xz....z......h.x............z.x...z...xz...  XR:Z:GA  XG:Z:CT
# 39741  XM:Z:.xz....z......h.x............z.x...z...xz...  XR:Z:GA  XG:Z:CT
# 39742  XM:Z:.xz....z......h.x............z.x...z...xz...  XR:Z:GA  XG:Z:CT
# 39743  XM:Z:.xz....z......h.x............z.x...z...xz...  XR:Z:GA  XG:Z:CT
#
#                        sample                 region  abs_flen  read_length
# 0      1-MYAAAA29TS_M525-M725  chr20:5297083-5297184       128           77
# 1      1-MYAAAA29TS_M525-M725  chr20:5297083-5297184       128           77
# 2      1-MYAAAA29TS_M525-M725  chr20:5297083-5297184       128           77
# 3      1-MYAAAA29TS_M525-M725  chr20:5297083-5297184       128           77
# 4      1-MYAAAA29TS_M525-M725  chr20:5297083-5297184       128           77
# ...                       ...                    ...       ...          ...
# 39739  1-MYAAAA29TS_M525-M725  chr20:5297083-5297184       146           76
# 39740  1-MYAAAA29TS_M525-M725  chr20:5297083-5297184       146           76
# 39741  1-MYAAAA29TS_M525-M725  chr20:5297083-5297184       146           76
# 39742  1-MYAAAA29TS_M525-M725  chr20:5297083-5297184       146           76
# 39743  1-MYAAAA29TS_M525-M725  chr20:5297083-5297184       146           76
#
# [39744 rows x 12 columns]
